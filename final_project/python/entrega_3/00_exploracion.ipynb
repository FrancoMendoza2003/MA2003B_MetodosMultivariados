# %%
import sys
import pandas as pd
import numpy as np

if ".." not in sys.path:
    sys.path.append("..")

from utils.const import (
    INTEREST_VARS,
    VARIABLE_COLORS,
    COMPLETE_DATASETS_PATH,
    SELECTED_ZONES,
    ALL_VARS,
)
from utils.plotting import (
    plot_series,
    box_plot,
    hist_plot,
    data_exploration,
)
from utils.stats import (
    print_variable_info,
    describe_variables,
    filter_final_data,
)

from utils.preprocessing import (
    mfill,
)

# %% [markdown]
# # Gráficas

# %% [markdown]
# ## NORTE2, NOROESTE2, SURESTE3

# %%
noroeste2 = pd.read_csv(
    "../../datos/01_complete_datasets/NOROESTE2_2020_2023.csv", parse_dates=["date"]
)
norte2 = pd.read_csv(
    "../../datos/01_complete_datasets/NORTE2_2020_2023.csv", parse_dates=["date"]
)
sureste3 = pd.read_csv(
    "../../datos/01_complete_datasets/SURESTE3_2020_2023.csv", parse_dates=["date"]
)

# %%
plot_series(sureste3, interest_vars=["date", "PRS"], title="", freq="D")

# %%
INTEREST_VARS
# Out:
# ['date', 'PM10', 'PM2.5', 'WSR', 'WDR', 'PRS']

# %%
plot_series(noroeste2, interest_vars=["date", "WDR"], title="", freq="D")

# %%
t = sureste3.copy().set_index("date")
t.isna().sum()
# Out:
# CO       2084
# NO       1467
# NO2      1263
# NOX      1240
# O3       3353
# PM10     1565
# PM2.5    3690
# PRS       967
# RAINF     911
# RH       1198
# SO2      2886
# SR        141
# TOUT      915
# WSR       939
# WDR       944
# dtype: int64

# %%
t = sureste3.copy()
t["O3"] = mfill(t["O3"])
t.isna().sum()
# Out:
# date        0
# CO       2084
# NO       1467
# NO2      1263
# NOX      1240
# O3          0
# PM10     1565
# PM2.5    3690
# PRS       967
# RAINF     911
# RH       1198
# SO2      2886
# SR        141
# TOUT      915
# WSR       939
# WDR       944
# dtype: int64

# %%
plot_series(t.reset_index(), interest_vars=["date", "O3"], title="", freq="D")

# %%
sureste3.set_index("date")["O3"].interpolate(method="time")
# Out:
# date
# 2020-01-01 00:00:00     NaN
# 2020-01-01 01:00:00    25.0
# 2020-01-01 02:00:00    22.0
# 2020-01-01 03:00:00    21.0
# 2020-01-01 04:00:00    22.0
#                        ...
# 2023-08-17 19:00:00    36.0
# 2023-08-17 20:00:00    29.0
# 2023-08-17 21:00:00    26.0
# 2023-08-17 22:00:00    25.0
# 2023-08-17 23:00:00    28.0
# Name: O3, Length: 31790, dtype: float64

# %%
hist_plot(noroeste2, interest_vars=INTEREST_VARS, title="")

# %% [markdown]
# ## OTRAS ZONAS

# %%
centro = pd.read_csv(
    "../../datos/01_complete_datasets/CENTRO_2020_2023.csv", parse_dates=["date"]
)
# plot_series(centro, title="", interest_vars=["date", "PRS"], freq="D")
plot_series(centro, title="", interest_vars=INTEREST_VARS, freq="D")

# %%
noreste = pd.read_csv(
    "../../datos/01_complete_datasets/NORESTE_2020_2023.csv", parse_dates=["date"]
)

plot_series(noreste, title="", interest_vars=INTEREST_VARS, freq="D")

# %%
noreste2 = pd.read_csv(
    "../../datos/01_complete_datasets/NORESTE2_2020_2023.csv", parse_dates=["date"]
)

plot_series(noreste2, title="", interest_vars=INTEREST_VARS, freq="D")

# %%
noroeste = pd.read_csv(
    "../../datos/01_complete_datasets/NOROESTE_2020_2023.csv", parse_dates=["date"]
)

plot_series(noroeste, title="", interest_vars=INTEREST_VARS, freq="D")

# %%
norte = pd.read_csv(
    "../../datos/01_complete_datasets/NORTE_2020_2023.csv", parse_dates=["date"]
)

plot_series(norte, title="", interest_vars=INTEREST_VARS, freq="D")

# %%
sur = pd.read_csv(
    "../../datos/01_complete_datasets/SUR_2020_2023.csv", parse_dates=["date"]
)

plot_series(sur, title="", interest_vars=INTEREST_VARS, freq="D")

# %%
sureste = pd.read_csv(
    "../../datos/01_complete_datasets/SURESTE_2020_2023.csv", parse_dates=["date"]
)

plot_series(sureste, title="", interest_vars=INTEREST_VARS, freq="D")

# %%
sureste2 = pd.read_csv(
    "../../datos/01_complete_datasets/SURESTE2_2020_2023.csv", parse_dates=["date"]
)

plot_series(sureste2, title="", interest_vars=INTEREST_VARS, freq="D")

# %%
suroeste = pd.read_csv(
    "../../datos/01_complete_datasets/SUROESTE_2020_2023.csv", parse_dates=["date"]
)

plot_series(suroeste, title="", interest_vars=INTEREST_VARS, freq="D")

# %%
suroeste2 = pd.read_csv(
    "../../datos/01_complete_datasets/SUROESTE2_2020_2023.csv", parse_dates=["date"]
)
plot_series(suroeste2, title="", interest_vars=INTEREST_VARS, freq="D")
# plot_series(suroeste2, title="", interest_vars=["date", "WSR"], freq="D")

# %% [markdown]
# # Calidad de datos

# %%
for zone_path in COMPLETE_DATASETS_PATH:
    zone = zone_path.split("/")[-1].split(".")[0].split("_")[0]
    print(f"===== {zone} =====")
    print_variable_info(
        df=pd.read_csv(zone_path, parse_dates=["date"]),
        variables=INTEREST_VARS,
    )
# Out:
# ===== NORTE2 =====
# Variable: date
# Tipo de Variable: Numérico
# Valores Posbles: [2020-01-01 00:00:00, 2023-08-17 23:00:00]
# Cantidad de Valores Nulos: 0/31790 -> 0.00%
# -----
#
# Variable: PM10
# Tipo de Variable: Numérico
# Valores Posbles: [2.0, 767.0]
# Cantidad de Valores Nulos: 1363/31790 -> 4.29%
# -----
#
# Variable: PM2.5
# Tipo de Variable: Numérico
# Valores Posbles: [1.0, 370.0]
# Cantidad de Valores Nulos: 5484/31790 -> 17.25%
# -----
#
# Variable: WSR
# Tipo de Variable: Numérico
# Valores Posbles: [0.1, 29.7]
# Cantidad de Valores Nulos: 338/31790 -> 1.06%
# -----
#
# Variable: WDR
# Tipo de Variable: Numérico
# Valores Posbles: [1.0, 360.0]
# Cantidad de Valores Nulos: 383/31790 -> 1.20%
# -----
#
# Variable: PRS
# Tipo de Variable: Numérico
# Valores Posbles: [680.8, 738.9]
# Cantidad de Valores Nulos: 390/31790 -> 1.23%
# -----
#
# ===== NOROESTE2 =====
# Variable: date
# Tipo de Variable: Numérico
# Valores Posbles: [2020-01-01 00:00:00, 2023-08-17 23:00:00]
# Cantidad de Valores Nulos: 0/31790 -> 0.00%
# -----
#
# Variable: PM10
# Tipo de Variable: Numérico
# Valores Posbles: [2.0, 763.0]
# Cantidad de Valores Nulos: 887/31790 -> 2.79%
# -----
#
# Variable: PM2.5
# Tipo de Variable: Numérico
# Valores Posbles: [2.01, 223.32]
# Cantidad de Valores Nulos: 3179/31790 -> 10.00%
# -----
#
# Variable: WSR
# Tipo de Variable: Numérico
# Valores Posbles: [0.1, 62.1]
# Cantidad de Valores Nulos: 1703/31790 -> 5.36%
# -----
#
# Variable: WDR
# Tipo de Variable: Numérico
# Valores Posbles: [1.0, 360.0]
# Cantidad de Valores Nulos: 3367/31790 -> 10.59%
# -----
#
# Variable: PRS
# Tipo de Variable: Numérico
# Valores Posbles: [680.0, 715.4]
# Cantidad de Valores Nulos: 1623/31790 -> 5.11%
# -----
#
# ===== SURESTE3 =====
# Variable: date
# Tipo de Variable: Numérico
# Valores Posbles: [2020-01-01 00:00:00, 2023-08-17 23:00:00]
# Cantidad de Valores Nulos: 0/31790 -> 0.00%
# -----
#
# Variable: PM10
# Tipo de Variable: Numérico
# Valores Posbles: [2.0, 766.0]
# Cantidad de Valores Nulos: 1565/31790 -> 4.92%
# -----
#
# Variable: PM2.5
# Tipo de Variable: Numérico
# Valores Posbles: [0.0, 192.0]
# Cantidad de Valores Nulos: 3690/31790 -> 11.61%
# -----
#
# Variable: WSR
# Tipo de Variable: Numérico
# Valores Posbles: [0.1, 42.0]
# Cantidad de Valores Nulos: 939/31790 -> 2.95%
# -----
#
# Variable: WDR
# Tipo de Variable: Numérico
# Valores Posbles: [1.0, 360.0]
# Cantidad de Valores Nulos: 944/31790 -> 2.97%
# -----
#
# Variable: PRS
# Tipo de Variable: Numérico
# Valores Posbles: [680.0, 747.6]
# Cantidad de Valores Nulos: 967/31790 -> 3.04%
# -----
#
# ===== CENTRO =====
# Variable: date
# Tipo de Variable: Numérico
# Valores Posbles: [2020-01-01 00:00:00, 2023-08-17 23:00:00]
# Cantidad de Valores Nulos: 0/31791 -> 0.00%
# -----
#
# Variable: PM10
# Tipo de Variable: Numérico
# Valores Posbles: [2.0, 735.0]
# Cantidad de Valores Nulos: 961/31791 -> 3.02%
# -----
#
# Variable: PM2.5
# Tipo de Variable: Numérico
# Valores Posbles: [0.0, 144.66]
# Cantidad de Valores Nulos: 3932/31791 -> 12.37%
# -----
#
# Variable: WSR
# Tipo de Variable: Numérico
# Valores Posbles: [0.7, 24.8]
# Cantidad de Valores Nulos: 584/31791 -> 1.84%
# -----
#
# Variable: WDR
# Tipo de Variable: Numérico
# Valores Posbles: [1.0, 360.0]
# Cantidad de Valores Nulos: 568/31791 -> 1.79%
# -----
#
# Variable: PRS
# Tipo de Variable: Numérico
# Valores Posbles: [689.4, 724.9]
# Cantidad de Valores Nulos: 566/31791 -> 1.78%
# -----
#
# ===== NORESTE =====
# Variable: date
# Tipo de Variable: Numérico
# Valores Posbles: [2020-01-01 00:00:00, 2023-08-17 23:00:00]
# Cantidad de Valores Nulos: 0/31790 -> 0.00%
# -----
#
# Variable: PM10
# Tipo de Variable: Numérico
# Valores Posbles: [2.0, 1000.0]
# Cantidad de Valores Nulos: 1085/31790 -> 3.41%
# -----
#
# Variable: PM2.5
# Tipo de Variable: Numérico
# Valores Posbles: [2.0, 406.52]
# Cantidad de Valores Nulos: 2185/31790 -> 6.87%
# -----
#
# Variable: WSR
# Tipo de Variable: Numérico
# Valores Posbles: [0.1, 127.5]
# Cantidad de Valores Nulos: 6532/31790 -> 20.55%
# -----
#
# Variable: WDR
# Tipo de Variable: Numérico
# Valores Posbles: [1.0, 360.0]
# Cantidad de Valores Nulos: 3671/31790 -> 11.55%
# -----
#
# Variable: PRS
# Tipo de Variable: Numérico
# Valores Posbles: [680.3, 734.7]
# Cantidad de Valores Nulos: 2230/31790 -> 7.01%
# -----
#
# ===== NORESTE2 =====
# Variable: date
# Tipo de Variable: Numérico
# Valores Posbles: [2020-01-01 00:00:00, 2023-08-17 23:00:00]
# Cantidad de Valores Nulos: 0/31790 -> 0.00%
# -----
#
# Variable: PM10
# Tipo de Variable: Numérico
# Valores Posbles: [2.0, 799.0]
# Cantidad de Valores Nulos: 1762/31790 -> 5.54%
# -----
#
# Variable: PM2.5
# Tipo de Variable: Numérico
# Valores Posbles: [2.0, 199.0]
# Cantidad de Valores Nulos: 4808/31790 -> 15.12%
# -----
#
# Variable: WSR
# Tipo de Variable: Numérico
# Valores Posbles: [0.1, 168.4]
# Cantidad de Valores Nulos: 6344/31790 -> 19.96%
# -----
#
# Variable: WDR
# Tipo de Variable: Numérico
# Valores Posbles: [-9999.0, 360.0]
# Cantidad de Valores Nulos: 4178/31790 -> 13.14%
# -----
#
# Variable: PRS
# Tipo de Variable: Numérico
# Valores Posbles: [655.4, 734.1]
# Cantidad de Valores Nulos: 889/31790 -> 2.80%
# -----
#
# ===== NOROESTE =====
# Variable: date
# Tipo de Variable: Numérico
# Valores Posbles: [2020-01-01 00:00:00, 2023-08-17 23:00:00]
# Cantidad de Valores Nulos: 0/31792 -> 0.00%
# -----
#
# Variable: PM10
# Tipo de Variable: Numérico
# Valores Posbles: [2.0, 671.0]
# Cantidad de Valores Nulos: 2019/31792 -> 6.35%
# -----
#
# Variable: PM2.5
# Tipo de Variable: Numérico
# Valores Posbles: [2.0, 442.0]
# Cantidad de Valores Nulos: 7293/31792 -> 22.94%
# -----
#
# Variable: WSR
# Tipo de Variable: Numérico
# Valores Posbles: [0.1, 58.5]
# Cantidad de Valores Nulos: 2191/31792 -> 6.89%
# -----
#
# Variable: WDR
# Tipo de Variable: Numérico
# Valores Posbles: [1.0, 360.0]
# Cantidad de Valores Nulos: 4685/31792 -> 14.74%
# -----
#
# Variable: PRS
# Tipo de Variable: Numérico
# Valores Posbles: [688.3, 727.7]
# Cantidad de Valores Nulos: 803/31792 -> 2.53%
# -----
#
# ===== NORTE =====
# Variable: date
# Tipo de Variable: Numérico
# Valores Posbles: [2020-01-01 00:00:00, 2023-08-17 23:00:00]
# Cantidad de Valores Nulos: 0/31791 -> 0.00%
# -----
#
# Variable: PM10
# Tipo de Variable: Numérico
# Valores Posbles: [2.0, 1001.0]
# Cantidad de Valores Nulos: 3642/31791 -> 11.46%
# -----
#
# Variable: PM2.5
# Tipo de Variable: Numérico
# Valores Posbles: [1.0, 384.02]
# Cantidad de Valores Nulos: 6228/31791 -> 19.59%
# -----
#
# Variable: WSR
# Tipo de Variable: Numérico
# Valores Posbles: [0.1, 35.2]
# Cantidad de Valores Nulos: 9276/31791 -> 29.18%
# -----
#
# Variable: WDR
# Tipo de Variable: Numérico
# Valores Posbles: [-9999.0, 360.0]
# Cantidad de Valores Nulos: 10524/31791 -> 33.10%
# -----
#
# Variable: PRS
# Tipo de Variable: Numérico
# Valores Posbles: [669.0, 738.9]
# Cantidad de Valores Nulos: 10569/31791 -> 33.25%
# -----
#
# ===== SURESTE =====
# Variable: date
# Tipo de Variable: Numérico
# Valores Posbles: [2020-01-01 00:00:00, 2023-08-17 23:00:00]
# Cantidad de Valores Nulos: 0/31793 -> 0.00%
# -----
#
# Variable: PM10
# Tipo de Variable: Numérico
# Valores Posbles: [2.0, 706.55]
# Cantidad de Valores Nulos: 1233/31793 -> 3.88%
# -----
#
# Variable: PM2.5
# Tipo de Variable: Numérico
# Valores Posbles: [2.0, 179.52]
# Cantidad de Valores Nulos: 2746/31793 -> 8.64%
# -----
#
# Variable: WSR
# Tipo de Variable: Numérico
# Valores Posbles: [0.3, 64.0]
# Cantidad de Valores Nulos: 606/31793 -> 1.91%
# -----
#
# Variable: WDR
# Tipo de Variable: Numérico
# Valores Posbles: [1.0, 360.0]
# Cantidad de Valores Nulos: 10355/31793 -> 32.57%
# -----
#
# Variable: PRS
# Tipo de Variable: Numérico
# Valores Posbles: [0.0, 740.0]
# Cantidad de Valores Nulos: 2386/31793 -> 7.50%
# -----
#
# ===== SURESTE2 =====
# Variable: date
# Tipo de Variable: Numérico
# Valores Posbles: [2020-01-01 00:00:00, 2023-08-17 23:00:00]
# Cantidad de Valores Nulos: 0/31791 -> 0.00%
# -----
#
# Variable: PM10
# Tipo de Variable: Numérico
# Valores Posbles: [2.0, 963.0]
# Cantidad de Valores Nulos: 2052/31791 -> 6.45%
# -----
#
# Variable: PM2.5
# Tipo de Variable: Numérico
# Valores Posbles: [2.0, 364.0]
# Cantidad de Valores Nulos: 5817/31791 -> 18.30%
# -----
#
# Variable: WSR
# Tipo de Variable: Numérico
# Valores Posbles: [0.1, 28.1]
# Cantidad de Valores Nulos: 3416/31791 -> 10.75%
# -----
#
# Variable: WDR
# Tipo de Variable: Numérico
# Valores Posbles: [1.0, 360.0]
# Cantidad de Valores Nulos: 1956/31791 -> 6.15%
# -----
#
# Variable: PRS
# Tipo de Variable: Numérico
# Valores Posbles: [686.5, 728.8]
# Cantidad de Valores Nulos: 2452/31791 -> 7.71%
# -----
#
# ===== SUROESTE =====
# Variable: date
# Tipo de Variable: Numérico
# Valores Posbles: [2020-01-01 00:00:00, 2023-08-17 23:00:00]
# Cantidad de Valores Nulos: 0/31792 -> 0.00%
# -----
#
# Variable: PM10
# Tipo de Variable: Numérico
# Valores Posbles: [2.0, 802.0]
# Cantidad de Valores Nulos: 1000/31792 -> 3.15%
# -----
#
# Variable: PM2.5
# Tipo de Variable: Numérico
# Valores Posbles: [2.0, 238.0]
# Cantidad de Valores Nulos: 1851/31792 -> 5.82%
# -----
#
# Variable: WSR
# Tipo de Variable: Numérico
# Valores Posbles: [0.1, 63.3]
# Cantidad de Valores Nulos: 590/31792 -> 1.86%
# -----
#
# Variable: WDR
# Tipo de Variable: Numérico
# Valores Posbles: [1.0, 360.0]
# Cantidad de Valores Nulos: 2613/31792 -> 8.22%
# -----
#
# Variable: PRS
# Tipo de Variable: Numérico
# Valores Posbles: [680.0, 738.9]
# Cantidad de Valores Nulos: 1694/31792 -> 5.33%
# -----
#
# ===== SUROESTE2 =====
# Variable: date
# Tipo de Variable: Numérico
# Valores Posbles: [2020-01-01 00:00:00, 2023-08-17 23:00:00]
# Cantidad de Valores Nulos: 0/31790 -> 0.00%
# -----
#
# Variable: PM10
# Tipo de Variable: Numérico
# Valores Posbles: [2.0, 999.0]
# Cantidad de Valores Nulos: 1789/31790 -> 5.63%
# -----
#
# Variable: PM2.5
# Tipo de Variable: Numérico
# Valores Posbles: [1.0, 120.0]
# Cantidad de Valores Nulos: 4089/31790 -> 12.86%
# -----
#
# Variable: WSR
# Tipo de Variable: Numérico
# Valores Posbles: [0.3, 227.1]
# Cantidad de Valores Nulos: 6671/31790 -> 20.98%
# -----
#
# Variable: WDR
# Tipo de Variable: Numérico
# Valores Posbles: [1.0, 360.0]
# Cantidad de Valores Nulos: 835/31790 -> 2.63%
# -----
#
# Variable: PRS
# Tipo de Variable: Numérico
# Valores Posbles: [707.9, 738.9]
# Cantidad de Valores Nulos: 346/31790 -> 1.09%
# -----
#
# ===== SUR =====
# Variable: date
# Tipo de Variable: Numérico
# Valores Posbles: [2020-01-01 00:00:00, 2023-08-17 23:00:00]
# Cantidad de Valores Nulos: 0/31788 -> 0.00%
# -----
#
# Variable: PM10
# Tipo de Variable: Numérico
# Valores Posbles: [2.0, 710.0]
# Cantidad de Valores Nulos: 949/31788 -> 2.99%
# -----
#
# Variable: PM2.5
# Tipo de Variable: Numérico
# Valores Posbles: [2.0, 97.0]
# Cantidad de Valores Nulos: 11460/31788 -> 36.05%
# -----
#
# Variable: WSR
# Tipo de Variable: Numérico
# Valores Posbles: [0.1, 134.8]
# Cantidad de Valores Nulos: 568/31788 -> 1.79%
# -----
#
# Variable: WDR
# Tipo de Variable: Numérico
# Valores Posbles: [1.0, 360.0]
# Cantidad de Valores Nulos: 10147/31788 -> 31.92%
# -----
#
# Variable: PRS
# Tipo de Variable: Numérico
# Valores Posbles: [691.8, 735.5]
# Cantidad de Valores Nulos: 339/31788 -> 1.07%
# -----
